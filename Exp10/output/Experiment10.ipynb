# %%
import cv2
import numpy as np

# %%
img = cv2.imread('/content/img.png')

# %%
mean = np.mean(img)
variance = np.var(img)

# %%
print(mean)
print(variance)

# %%
cv2.imwrite("mean.jpg",mean)
cv2.imwrite("variance.jpg",variance)
